# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../data/USDTZUSD.csv')
s_to_ns = 1e9
df['time'] = (df['time']*s_to_ns).astype('datetime64[ns]')
display(df.tail(5))
df['close'].plot()
# Out:
#                    time    open    high     low   close    vwap  volume  count
# 856 2018-12-01 16:42:00  0.9888  0.9888  0.9888  0.9888  0.0000     0.0      0
# 857 2018-12-01 16:43:00  0.9888  0.9892  0.9888  0.9892  0.9892  3708.0      1
# 858 2018-12-01 16:44:00  0.9892  0.9892  0.9892  0.9892  0.0000     0.0      0
# 859 2018-12-01 16:45:00  0.9892  0.9892  0.9892  0.9892  0.0000     0.0      0
# 860 2018-12-01 16:46:00  0.9888  0.9888  0.9888  0.9888  0.9888  1000.0      1

# %%
d = df['time'].shift(1)
d = (df['time'] - d).iloc[1:]
display(d.tail(5))
d[(d == pd.Timedelta(60000000000*2))]
# Out:
# 856   00:01:00
# 857   00:01:00
# 858   00:01:00
# 859   00:01:00
# 860   00:01:00
# Name: time, dtype: timedelta64[ns]
# 43   00:02:00
# 47   00:02:00
# 94   00:02:00
# Name: time, dtype: timedelta64[ns]

# %%
display(df.iloc[40:50])
# Out:
#                   time    open    high     low   close    vwap       volume  \
# 40 2018-12-01 03:03:00  0.9842  0.9842  0.9842  0.9842  0.0000     0.000000
# 41 2018-12-01 03:04:00  0.9842  0.9842  0.9842  0.9842  0.0000     0.000000
# 42 2018-12-01 03:05:00  0.9842  0.9842  0.9842  0.9842  0.0000     0.000000
# 43 2018-12-01 03:07:00  0.9842  0.9842  0.9842  0.9842  0.0000     0.000000
# 44 2018-12-01 03:08:00  0.9842  0.9842  0.9842  0.9842  0.0000     0.000000
# 45 2018-12-01 03:09:00  0.9842  0.9842  0.9842  0.9842  0.0000     0.000000
# 46 2018-12-01 03:10:00  0.9842  0.9842  0.9824  0.9824  0.9834  1022.442081
# 47 2018-12-01 03:12:00  0.9824  0.9824  0.9824  0.9824  0.0000     0.000000
# 48 2018-12-01 03:13:00  0.9824  0.9824  0.9824  0.9824  0.0000     0.000000
# 49 2018-12-01 03:14:00  0.9824  0.9824  0.9824  0.9824  0.0000     0.000000
#
#     count
# 40      0
# 41      0
# 42      0
# 43      0
# 44      0
# 45      0
# 46      6
# 47      0
# 48      0
# 49      0
